# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(1, '/viscam/projects/audio_nerf/transfer/devocalization/masonstuff/src')
import spectrogram
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Example Conversions

# %%
conv = spectrogram.conv_2s_to_256_256
plt.imshow(conv.audio_to_mel(ref[0]).cpu().numpy())
print(conv.audio_to_mel(ref[0]).shape)
# Out:
# torch.Size([256, 257])

# %% [markdown]
# ### Comparisons

# %%
plt.plot(conv.mel_to_audio(conv.audio_to_mel(ref[0])).cpu().numpy())
plt.plot(ref[0].cpu().numpy())

# %%
from IPython.display import Audio
print("Ground Truth")
display(Audio(ref[0].cpu().numpy(), rate=22050))
print("Reconstruction")
display(Audio(conv.mel_to_audio(conv.audio_to_mel(ref[0])).cpu().numpy(), rate=22050))
# Out:
# Ground Truth
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Reconstruction
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Spectrogram Dataset

# %%
spectrogram.save_mel_spectrograms("/viscam/projects/audio_nerf/transfer/devocalization/data/processed_framewise/imitations.npy", "/viscam/projects/audio_nerf/transfer/devocalization/data/processed_framewise/imitations_spec_256.npy")

# %%
spectrogram.save_mel_spectrograms("/viscam/projects/audio_nerf/transfer/devocalization/data/processed_framewise/reference.npy", "/viscam/projects/audio_nerf/transfer/devocalization/data/processed_framewise/reference_spec_256.npy")
